# %%
# !pip install ultralytics
# Out:
# /bin/bash: /home/muhlabws4/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/92/aa/202ca14d0987dfc1a0cb521dee9ff67f877eed763dd8d1a1ab9c764bcc3a/ultralytics-8.0.165-py3-none-any.whl.metadata
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 2.6 MB/s eta 0:00:000:00:010:00:0101
# ...

# %%
from ultralytics import YOLO
from PIL import Image

# %%
import numpy
numpy.version.version
# Out:
# '1.24.3'

# %%
#modelin yüklenmesi
modelCls = YOLO('yolov8n.pt')
modelSeg = YOLO('yolov8n-seg.pt')
modelPose = YOLO('yolov8n-pose.pt')

# %%
myModel = YOLO('objDet2Best.pt')
myModel = YOLO('yolov8n-seg.pt')

# %%
myKeyModel = YOLO('/home/muhlabws4/dosyalar/YoloTrain/runs/pose/train/weights/best.pt')

# %%
video = '/home/muhlabws4/Belgeler/tkd/tkd.mp4'
resultVideo = myKeyModel.predict(source=video, save=True, conf=0.3,visualize=False)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 2 chongs, 2 hongs, 59.1ms
# video 1/1 (2/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 2 chongs, 2 hongs, 2.8ms
# video 1/1 (3/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 2 chongs, 1 hakem, 2 hongs, 2.7ms
# video 1/1 (4/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 2 chongs, 2 hongs, 3.0ms
# ...

# %%
img = Image.open('/home/muhlabws4/dosyalar/frames/ilk/frame_9600.jpg')
result = modelCls.predict(source=img, save=True, conf=0.5,save_conf=True)
# Out:
# 0: 384x640 7 persons, 2.5ms
# Speed: 1.1ms preprocess, 2.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
#resim tanıma
img = Image.open('/home/muhlabws4/dosyalar/frames/TurkishOpen2023-Kyorugi-Day1-Court5/frame_16320.jpg')
result = modelSeg.predict(source=img, save=True, conf=0.5,visualize=False)
# Out:
# 0: 384x640 3 persons, 53.4ms
# Speed: 0.8ms preprocess, 53.4ms inference, 66.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict4

# %%
img = Image.open('/home/muhlabws4/dosyalar/frames/TurkishOpen2023-Kyorugi-Day1-Court5/frame_16080.jpg')
result = modelPose.predict(source=img, save=True, conf=0.2,visualize=False)
# Out:
# 0: 384x640 2 persons, 2.9ms
# Speed: 7.0ms preprocess, 2.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/pose/predict3

# %%
#video
video = '/home/muhlabws4/Belgeler/tkd/tkd.mp4'
resultVideo = modelSeg.predict(source=video, save=True, conf=0.3,visualize=False)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 12 persons, 2 chairs, 2.9ms
# video 1/1 (2/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 14 persons, 1 chair, 3.0ms
# video 1/1 (3/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 14 persons, 1 chair, 3.1ms
# video 1/1 (4/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 14 persons, 2.8ms
# ...

# %%
video = '/home/muhlabws4/Belgeler/tkd/tkd.mp4'
segVideo = '/home/muhlabws4/dosyalar/runs/segment/predict'
resultVideo = modelPose.predict(source=segVideo, save=True, conf=0.5,visualize=False)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# image 1/2 /home/muhlabws4/dosyalar/runs/segment/predict/tkdresim2.jpg: 384x640 1 person, 3.0ms
# video 2/2 (1/162) /home/muhlabws4/dosyalar/runs/segment/predict/tkd.avi: 384x640 2 persons, 3.0ms
# video 2/2 (2/162) /home/muhlabws4/dosyalar/runs/segment/predict/tkd.avi: 384x640 2 persons, 2.9ms
# video 2/2 (3/162) /home/muhlabws4/dosyalar/runs/segment/predict/tkd.avi: 384x640 3 persons, 2.9ms
# ...

# %%
img = Image.open('tkdresim2.jpg')
result = modelPose.predict(source=img, save=True)

for r in result:
    print(r.keypoints)
    
for r in result:
    print(r.probs)  # print the Probs object containing the detected class probabilities
    
    
# Show the results
for r in result:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# 0: 384x640 4 persons, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/pose/predict2
# ultralytics.engine.results.Keypoints object with attributes:
#
# conf: tensor([[0.8660, 0.2959, 0.8759, 0.2298, 0.9556, 0.9687, 0.9968, 0.7930, 0.9925, 0.7610, 0.9775, 0.9905, 0.9972, 0.9814, 0.9942, 0.9087, 0.9572],
#         [0.7898, 0.4839, 0.5482, 0.3631, 0.4335, 0.9831, 0.9786, 0.9760, 0.9675, 0.9541, 0.9482, 0.9974, 0.9967, 0.9914, 0.9899, 0.9390, 0.9302],
#         [0.7183, 0.4083, 0.6057, 0.2197, 0.4424, 0.8553, 0.9689, 0.7528, 0.9646, 0.7225, 0.9310, 0.9876, 0.9946, 0.9783, 0.9907, 0.9400, 0.9662],
#         [0.9162, 0.9403, 0.8715, 0.8512, 0.4789, 0.8090, 0.7285, 0.2831, 0.1355, 0.1931, 0.1035, 0.1183, 0.0994, 0.0274, 0.0206, 0.0195, 0.0156]], device='cuda:0')
# data: tensor([[[3.1204e+02, 8.0494e+01, 8.6597e-01],
#          [3.1029e+02, 7.5826e+01, 2.9591e-01],
#          [3.0650e+02, 7.2978e+01, 8.7589e-01],
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="zG8V8GVZS3hgbRfuYu07")
project = rf.workspace("taekwondoproject").project("taekwondo-mndkr")
dataset = project.version(1).download("yolov8")


https://app.roboflow.com/ds/YIeqqifQQl?key=84LFelPXTR
    
    
    
curl -L "https://app.roboflow.com/ds/YIeqqifQQl?key=84LFelPXTR" &gt; roboflow.zip; unzip roboflow.zip; rm roboflow.zip
