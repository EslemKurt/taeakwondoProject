# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.9.17 torch-2.0.0+cu118 CUDA:0 (NVIDIA RTX A4000, 16109MiB)
# Setup complete ✅ (24 CPUs, 62.5 GB RAM, 151.0/917.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from roboflow import Roboflow

# %%
modelSeg = YOLO('tySegModelV1.pt')
modelPose = YOLO('/home/muhlabws4/dosyalar/YoloTrain/runs/pose/train2/weights/best.pt')

# %%
# !pip install onnx
# Out:
# /bin/bash: /home/muhlabws4/miniconda3/envs/tf/lib/python3.9/site-packages/cv2/../../../../lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...

# %%
modelSeg.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.9.17 torch-2.0.0+cu118 CPU
# YOLOv8n-seg summary (fused): 195 layers, 3259234 parameters, 0 gradients, 12.0 GFLOPs
#
# PyTorch: starting from tySegModelV1.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 42, 8400), (1, 32, 160, 160)) (6.4 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 0.4s, saved as tySegModelV1.onnx (12.6 MB)
#
# Export complete (0.8s)
# Results saved to /home/muhlabws4/dosyalar/YoloTrain
# Predict:         yolo predict task=segment model=tySegModelV1.onnx imgsz=640
# Validate:        yolo val task=segment model=tySegModelV1.onnx imgsz=640 data=./data/tkdseg/dataset.yaml
# Visualize:       https://netron.app
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# 'tySegModelV1.onnx'

# %%
modelPose.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.9.17 torch-2.0.0+cu118 CPU
# YOLOv8n-pose summary (fused): 187 layers, 3290549 parameters, 0 gradients, 9.2 GFLOPs
#
# PyTorch: starting from /home/muhlabws4/dosyalar/YoloTrain/runs/pose/train2/weights/best.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 59, 13125) (6.5 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 0.5s, saved as /home/muhlabws4/dosyalar/YoloTrain/runs/pose/train2/weights/best.onnx (13.0 MB)
#
# Export complete (0.7s)
# Results saved to /home/muhlabws4/dosyalar/YoloTrain/runs/pose/train2/weights
# Predict:         yolo predict task=pose model=/home/muhlabws4/dosyalar/YoloTrain/runs/pose/train2/weights/best.onnx imgsz=800
# Validate:        yolo val task=pose model=/home/muhlabws4/dosyalar/YoloTrain/runs/pose/train2/weights/best.onnx imgsz=800 data=./data/tkdKeypoint/dataset.yaml
# Visualize:       https://netron.app
# ...

# %%
resultsSeg = modelSeg.track(source="/home/muhlabws4/Belgeler/tkd/tkd.mp4", conf=0.3, iou=0.7, save=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 1 chong, 2 govdes, 1 hakem, 1 hong, 2 kafas, 1 saha, 55.9ms
# video 1/1 (2/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 1 chong, 2 govdes, 1 hakem, 1 hong, 2 kafas, 1 saha, 2.9ms
# video 1/1 (3/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 384x640 1 chong, 2 govdes, 1 hakem, 1 hong, 2 kafas, 1 saha, 2.7ms
# ...

# %%
resultsPose = modelPose.track(source="/home/muhlabws4/Belgeler/tkd/tkd.mp4", conf=0.6, iou=0.7, save=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 1 hakem, 2 hongs, 4.6ms
# video 1/1 (2/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 1 hakem, 2 hongs, 2.7ms
# video 1/1 (3/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 1 hakem, 1 hong, 2.7ms
# video 1/1 (4/162) /home/muhlabws4/Belgeler/tkd/tkd.mp4: 480x800 1 hakem, 1 hong, 2.7ms
# ...

# %%
resul = modelPose.predict(source="runs/segment/track2/tkd.avi", conf=0.3, save=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/162) /home/muhlabws4/dosyalar/YoloTrain/runs/segment/track2/tkd.avi: 480x800 1 hong, 4.7ms
# video 1/1 (2/162) /home/muhlabws4/dosyalar/YoloTrain/runs/segment/track2/tkd.avi: 480x800 1 hong, 2.7ms
# video 1/1 (3/162) /home/muhlabws4/dosyalar/YoloTrain/runs/segment/track2/tkd.avi: 480x800 1 chong, 1 hong, 2.7ms
# video 1/1 (4/162) /home/muhlabws4/dosyalar/YoloTrain/runs/segment/track2/tkd.avi: 480x800 2 hongs, 2.9ms
# ...
