# %%
import tensorflow as tf

import numpy as np
import os
from tensorflow import keras
#import keras
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, KFold

from keras_preprocessing.image import load_img, img_to_array
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
data_path = "/home/muhlabws4/Belgeler/Pet"

# %%
class_folders = os.listdir(data_path)

# %%
images = []
labels = []

# %%
for i , class_name in enumerate(class_folders):
    class_folder_path = os.path.join(data_path, class_name)
    class_images = os.listdir(class_folder_path)
    
    for img_name in class_images:
        img_path = os.path.join(class_folder_path, img_name)
        img = load_img(img_path, target_size=(128,128))
        img_array = img_to_array(img) /255.0
        images.append(img_array)
        labels.append(class_name)

# %%
X = np.array(images)
y = np.array(labels)

# %%
label_encoder = LabelEncoder()
y_encoder = label_encoder.fit_transform(y)

# %%
X_shuf, y_shuf = X, y_encoder

# %%
train_images, test_images, train_labels, test_labels = train_test_split(X_shuf, y_shuf, test_size=0.2, random_state=42)

# %%
print(X.shape)
print(y.shape)
print(y_encoder.shape)

# %%
class_names = ['angry', 'other','sad', 'happy']

# %%
def cross_validation(model, X, y, n_splits=5, epochs=5, batch_size=32):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    #model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    #result = []
    for train_inx, val_inx in kfold.split(X):
        X_train, X_val = X[train_inx], X[val_inx]
        y_train, y_val = y[train_inx], y[val_inx]
        
        model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        a = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2, class_weight={0:3,1:4,2:3,3:3})
        #model.fit(X_train, y_train, epochs=epochs)
        #result.append(a.history['val_accuracy'])
        
    #return result

# %%
def gosterTrain(index):
    plt.figure(figsize=(15,2))
    plt.imshow(train_images[index])
    plt.title(class_names[train_labels[index]])

# %%
def gosterTest(index):
    plt.figure(figsize=(15,2))
    plt.imshow(test_images[index])
    plt.title(class_names[test_labels[index]])

# %%
gosterTrain(10)

# %%
gosterTest(70)

# %%
model = models.Sequential([
    #cnn
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=(128,128,3)),
    layers.MaxPooling2D((2,2)),
    #tf.keras.layers.Dropout(0.2),
    layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    #tf.keras.layers.Dropout(0.2),
    #dense
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    #tf.keras.layers.Dropout(0.2),
    layers.Dense(4,activation='softmax')
])
#model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.fit(train_images, train_labels, epochs=10)
# Out:
# 2023-08-11 13:44:50.649851: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.666628: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.666777: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.668124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.668213: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.668269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.819411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.819520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.819581: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-11 13:44:50.819635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1119 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(128, 128,3)),

    tf.keras.layers.Dense(256, activation='relu'),

    tf.keras.layers.Dense(10)
])

#model2.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
result = cross_validation(model, train_images, train_labels, n_splits=3, epochs=3, batch_size=32)
# Out:
# Epoch 1/3
# 2023-08-11 13:44:52.689598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-08-11 13:44:52.747480: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-08-11 13:44:52.836950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-11 13:44:52.856851: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x447e4e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-11 13:44:52.856867: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-08-11 13:44:52.861479: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-11 13:44:52.907448: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-08-11 13:44:52.943386: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/17 - 2s - loss: 8.5872 - accuracy: 0.2552 - 2s/epoch - 121ms/step
# Epoch 2/3
# 17/17 - 0s - loss: 4.4585 - accuracy: 0.2702 - 218ms/epoch - 13ms/step
# Epoch 3/3
# 17/17 - 0s - loss: 4.3077 - accuracy: 0.3583 - 226ms/epoch - 13ms/step
# Epoch 1/3
# 17/17 - 1s - loss: 4.1323 - accuracy: 0.3921 - 941ms/epoch - 55ms/step
# Epoch 2/3
# 17/17 - 0s - loss: 3.2440 - accuracy: 0.6191 - 251ms/epoch - 15ms/step
# Epoch 3/3
# 17/17 - 0s - loss: 2.3025 - accuracy: 0.7580 - 229ms/epoch - 13ms/step
# Epoch 1/3
# 17/17 - 1s - loss: 3.0321 - accuracy: 0.6255 - 1s/epoch - 70ms/step
# Epoch 2/3
# 2023-08-11 13:44:57.591076: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 288.40MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 17/17 - 0s - loss: 1.8571 - accuracy: 0.7903 - 236ms/epoch - 14ms/step
# Epoch 3/3
# 17/17 - 0s - loss: 1.0496 - accuracy: 0.9007 - 270ms/epoch - 16ms/step

# %%
for i, resul in enumerate(result):
    print(f"Fold {i+1} Başarı Değeri:", resul[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 for i, resul in enumerate(result):
#       2     print(f"Fold {i+1} Başarı Değeri:", resul[i])
#
# TypeError: 'NoneType' object is not iterable

# %%
sonuc = cross_validation(model2, train_images, train_labels, n_splits=4, epochs=4, batch_size=32)
# Out:
# Epoch 1/4
# 19/19 - 1s - loss: 8.9617 - accuracy: 0.0150 - 578ms/epoch - 30ms/step
# Epoch 2/4
# 19/19 - 0s - loss: 7.4681 - accuracy: 0.0000e+00 - 129ms/epoch - 7ms/step
# Epoch 3/4
# 19/19 - 0s - loss: 7.4681 - accuracy: 0.0000e+00 - 90ms/epoch - 5ms/step
# Epoch 4/4
# 19/19 - 0s - loss: 7.4681 - accuracy: 0.0000e+00 - 108ms/epoch - 6ms/step
# Epoch 1/4
# 19/19 - 0s - loss: 7.4642 - accuracy: 0.0000e+00 - 473ms/epoch - 25ms/step
# Epoch 2/4
# 19/19 - 0s - loss: 7.4642 - accuracy: 0.0000e+00 - 109ms/epoch - 6ms/step
# Epoch 3/4
# 19/19 - 0s - loss: 7.4642 - accuracy: 0.0000e+00 - 122ms/epoch - 6ms/step
# Epoch 4/4
# 19/19 - 0s - loss: 7.4642 - accuracy: 0.0000e+00 - 58ms/epoch - 3ms/step
# 2023-08-11 13:45:11.624346: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.50MiB (rounded to 117964800)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-08-11 13:45:11.624412: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-08-11 13:45:11.624436: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 101, Chunks in use: 101. 25.2KiB allocated for chunks. 25.2KiB in use in bin. 4.2KiB client-requested in use in bin.
# 2023-08-11 13:45:11.624449: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 7, Chunks in use: 7. 3.5KiB allocated for chunks. 3.5KiB in use in bin. 3.5KiB client-requested in use in bin.
# 2023-08-11 13:45:11.624462: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 13, Chunks in use: 13. 13.2KiB allocated for chunks. 13.2KiB in use in bin. 13.0KiB client-requested in use in bin.
# 2023-08-11 13:45:11.624474: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624486: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 10, Chunks in use: 10. 67.2KiB allocated for chunks. 67.2KiB in use in bin. 58.2KiB client-requested in use in bin.
# 2023-08-11 13:45:11.624499: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 7, Chunks in use: 7. 70.5KiB allocated for chunks. 70.5KiB in use in bin. 60.9KiB client-requested in use in bin.
# 2023-08-11 13:45:11.624509: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 31.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624519: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624529: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624538: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624549: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 6, Chunks in use: 6. 1.69MiB allocated for chunks. 1.69MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2023-08-11 13:45:11.624563: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 1, Chunks in use: 1. 545.5KiB allocated for chunks. 545.5KiB in use in bin. 288.0KiB client-requested in use in bin.
# 2023-08-11 13:45:11.624572: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624582: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624592: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 1, Chunks in use: 0. 6.00MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624602: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624614: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 7, Chunks in use: 6. 189.59MiB allocated for chunks. 168.75MiB in use in bin. 168.75MiB client-requested in use in bin.
# 2023-08-11 13:45:11.624635: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 6, Chunks in use: 6. 287.72MiB allocated for chunks. 287.72MiB in use in bin. 268.12MiB client-requested in use in bin.
# 2023-08-11 13:45:11.624646: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 6, Chunks in use: 5. 634.13MiB allocated for chunks. 525.00MiB in use in bin. 525.00MiB client-requested in use in bin.
# 2023-08-11 13:45:11.624656: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624666: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-11 13:45:11.624677: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 112.50MiB was 64.00MiB, Chunk State:
# 2023-08-11 13:45:11.624699: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 109.13MiB | Requested Size: 48.00MiB | in_use: 0 | bin_num: 18, prev:   Size: 48.00MiB | Requested Size: 48.00MiB | in_use: 1 | bin_num: -1
# 2023-08-11 13:45:11.624707: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 1174274048
# 2023-08-11 13:45:11.624720: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000000 of size 256 next 1
# 2023-08-11 13:45:11.624729: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000100 of size 1280 next 2
# 2023-08-11 13:45:11.624737: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000600 of size 256 next 3
# 2023-08-11 13:45:11.624744: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000700 of size 256 next 4
# 2023-08-11 13:45:11.624752: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000800 of size 256 next 6
# 2023-08-11 13:45:11.624760: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000900 of size 256 next 7
# 2023-08-11 13:45:11.624767: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000a00 of size 256 next 5
# 2023-08-11 13:45:11.624775: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000b00 of size 256 next 8
# 2023-08-11 13:45:11.624784: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000c00 of size 512 next 13
# 2023-08-11 13:45:11.624792: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000e00 of size 256 next 11
# 2023-08-11 13:45:11.624800: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136000f00 of size 256 next 12
# 2023-08-11 13:45:11.624808: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001000 of size 256 next 18
# 2023-08-11 13:45:11.624815: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001100 of size 256 next 16
# 2023-08-11 13:45:11.624823: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001200 of size 256 next 17
# 2023-08-11 13:45:11.624831: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001300 of size 256 next 22
# 2023-08-11 13:45:11.624838: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001400 of size 256 next 23
# 2023-08-11 13:45:11.624846: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001500 of size 256 next 21
# 2023-08-11 13:45:11.624854: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001600 of size 1024 next 24
# 2023-08-11 13:45:11.624862: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001a00 of size 256 next 27
# 2023-08-11 13:45:11.624869: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001b00 of size 256 next 30
# 2023-08-11 13:45:11.624877: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001c00 of size 256 next 32
# 2023-08-11 13:45:11.624884: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001d00 of size 256 next 25
# 2023-08-11 13:45:11.624894: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136001e00 of size 1024 next 26
# 2023-08-11 13:45:11.624902: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136002200 of size 256 next 31
# 2023-08-11 13:45:11.624909: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136002300 of size 256 next 35
# 2023-08-11 13:45:11.624917: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa136002400 of size 256 next 36
# 2023-08-11 13:45:11.624925: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fa
I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fa1752bdc00 of size 114435072 next 18446744073709551615
# 2023-08-11 13:45:11.625956: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-08-11 13:45:11.625966: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 101 Chunks of size 256 totalling 25.2KiB
# 2023-08-11 13:45:11.625975: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 512 totalling 3.5KiB
# 2023-08-11 13:45:11.625983: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 12 Chunks of size 1024 totalling 12.0KiB
# 2023-08-11 13:45:11.625991: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-08-11 13:45:11.625999: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4864 totalling 4.8KiB
# 2023-08-11 13:45:11.626007: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 6912 totalling 40.5KiB
# 2023-08-11 13:45:11.626014: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7168 totalling 7.0KiB
# 2023-08-11 13:45:11.626022: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7424 totalling 7.2KiB
# 2023-08-11 13:45:11.626030: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7936 totalling 7.8KiB
# 2023-08-11 13:45:11.626038: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 8192 totalling 8.0KiB
# 2023-08-11 13:45:11.626046: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 10240 totalling 50.0KiB
# 2023-08-11 13:45:11.626054: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12800 totalling 12.5KiB
# 2023-08-11 13:45:11.626062: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 294912 totalling 1.69MiB
# 2023-08-11 13:45:11.626070: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 558592 totalling 545.5KiB
# 2023-08-11 13:45:11.626078: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 29491200 totalling 168.75MiB
# 2023-08-11 13:45:11.626086: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 50035712 totalling 47.72MiB
# 2023-08-11 13:45:11.626095: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 50331648 totalling 240.00MiB
# 2023-08-11 13:45:11.626103: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 104792064 totalling 199.88MiB
# 2023-08-11 13:45:11.626111: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 104988672 totalling 100.12MiB
# 2023-08-11 13:45:11.626119: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 117964800 totalling 225.00MiB
# 2023-08-11 13:45:11.626129: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 983.86MiB
# 2023-08-11 13:45:11.626138: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 1174274048 memory_limit_: 1174274048 available bytes: 0 curr_region_allocation_bytes_: 2348548096
# 2023-08-11 13:45:11.626153: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      1174274048
# InUse:                      1031655680
# MaxInUse:                   1150645760
# NumAllocs:                       17229
# MaxAllocSize:                511099904
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-08-11 13:45:11.626174: W tensorflow/tsl/framework/bfc_allocator.cc:497] ****_**************************************************************************************_________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sonuc = cross_validation(model2, train_images, train_labels, n_splits=4, epochs=4, batch_size=32)
#
# Cell In[12], line 10, in cross_validation(model, X, y, n_splits, epochs, batch_size)
#       7 y_train, y_val = y[train_inx], y[val_inx]
#       9 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 10 a = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2, class_weight={0:3,1:4,2:3,3:3})
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:98, in convert_to_eager_tensor(value, ctx, dtype)
#      96     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97 ctx.ensure_initialized()
# ---> 98 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
for i, resul in enumerate(sonuc):
    print(f"Fold {i+1} Başarı Değeri:", resul[i])

# %%
#model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#model2.fit(train_images, train_labels, epochs=5)

# %%
#model.fit(train_images, train_labels, epochs=8)

# %%
model.evaluate(test_images, test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.evaluate(test_images, test_labels)
#
# NameError: name 'model' is not defined

# %%
model2.evaluate(test_images, test_labels)

# %%
tahminler = model.predict(test_images)

# %%
y_pred_classes = np.argmax(tahminler,axis=1)

# %%
tahminler[:7]

# %%
np.argmax(tahminler[7])
# Out:
# 2

# %%
test_labels
# Out:
# array([0, 0, 0, 0, 1, 0, 0, 0, 3, 2, 3, 2, 0, 3, 3, 3, 1, 3, 3, 1, 0, 2,
#        1, 0, 2, 2, 2, 3, 3, 3, 1, 2, 0, 1, 1, 2, 0, 0, 3, 2, 1, 2, 1, 3,
#        1, 1, 3, 0, 1, 3, 0, 3, 1, 0, 2, 2, 0, 2, 2, 3, 1, 2, 0, 2, 0, 0,
#        0, 3, 2, 0, 2, 1, 0, 0, 1, 1, 0, 2, 0, 1, 0, 2, 1, 2, 1, 0, 3, 0,
#        3, 1, 1, 1, 0, 2, 3, 1, 3, 2, 2, 3, 0, 1, 3, 1, 0, 0, 0, 3, 2, 3,
#        0, 3, 3, 3, 2, 1, 2, 3, 0, 1, 3, 1, 0, 1, 2, 0, 0, 1, 3, 3, 0, 3,
#        1, 3, 0, 2, 2, 2, 2, 2, 2, 2, 0, 1, 3, 3, 3, 2, 3, 1, 0, 2, 3, 1,
#        3, 1, 1, 0, 2, 3, 0, 3, 0, 0, 3, 0, 1, 0, 1, 1, 1, 1, 2, 3, 1, 1,
#        1, 1, 3, 0, 1, 0, 1, 0, 3, 2, 1, 1, 3, 0, 3, 3, 0, 2, 2, 1, 1, 2,
#        0, 2])

# %%
y_pred_classes
# Out:
# array([0, 0, 0, 0, 3, 0, 1, 2, 2, 2, 1, 2, 1, 1, 2, 3, 1, 3, 2, 1, 2, 3,
#        2, 1, 2, 2, 2, 2, 1, 0, 2, 3, 2, 0, 0, 2, 2, 2, 2, 0, 1, 2, 2, 3,
#        1, 1, 2, 0, 3, 2, 2, 2, 2, 2, 2, 2, 0, 1, 2, 2, 1, 2, 0, 0, 2, 0,
#        0, 3, 2, 0, 0, 1, 2, 0, 0, 1, 1, 1, 1, 1, 1, 3, 2, 2, 3, 2, 1, 0,
#        2, 1, 2, 1, 1, 2, 2, 2, 2, 3, 2, 3, 0, 1, 2, 1, 3, 1, 2, 2, 2, 3,
#        2, 3, 0, 2, 1, 1, 0, 1, 0, 2, 3, 3, 3, 2, 1, 2, 1, 1, 2, 1, 2, 3,
#        2, 3, 0, 2, 2, 2, 1, 3, 0, 2, 0, 3, 1, 1, 2, 2, 3, 2, 1, 2, 2, 2,
#        2, 1, 2, 2, 3, 0, 0, 3, 0, 0, 3, 0, 2, 0, 2, 0, 1, 3, 2, 2, 1, 0,
#        3, 1, 2, 1, 1, 2, 3, 0, 2, 0, 3, 2, 3, 1, 2, 1, 0, 2, 2, 3, 1, 2,
#        1, 3])

# %%
print(classification_report(test_labels, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.44      0.52        55
#            1       0.44      0.40      0.42        52
#            2       0.32      0.59      0.42        44
#            3       0.42      0.29      0.34        49
#
#     accuracy                           0.42       200
#    macro avg       0.45      0.43      0.42       200
# weighted avg       0.46      0.42      0.43       200

# %%
conf_matrix = confusion_matrix(test_labels, y_pred_classes)

# %%
print(conf_matrix)
# Out:
# [[24 13 16  2]
#  [ 5 21 16 10]
#  [ 6  5 26  7]
#  [ 3  9 23 14]]

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix)

# %%
cm_display.plot()
plt.show()

# %%
def tablo(confusion_matrix, index):
    TP=confusion_matrix[index][index]
    FN=sum(confusion_matrix[index][:index])+sum(confusion_matrix[index][index+1:])
    FP=sum(np.transpose(confusion_matrix)[index][:index])+sum(np.transpose(confusion_matrix)[index][index+1:])
    TN=sum(sum(confusion_matrix))-TP-FN-FP
    return TP,TN,FP,FN

# %%
def acc(confusion_matrix,index):
    TP,TN,FP,FN = tablo(confusion_matrix,index)
    acc = (TN+TP)/(TN+TP+FP+FN)
    return acc

# %%
def precision(confusion_matrix,index):
    TP,TN,FP,FN = tablo(confusion_matrix,index)
    p = (TP)/(TP+FP)
    return p

# %%
def sensitivity(confusion_matrix,index):
    TP,TN,FP,FN = tablo(confusion_matrix,index)
    sn = (TP)/(TP+FN)
    return sn

# %%
def specificity(confusion_matrix,index):
    TP,TN,FP,FN = tablo(confusion_matrix,index)
    sp = (TN)/(TN+FP)
    return sp

# %%
def f_score(confusion_matrix,index):
    p=precision(confusion_matrix,index)
    sn=sensitivity(confusion_matrix,index)
    f_score = ((p*sn)/(p+sn))*2
    return f_score

# %%
def recall(confusion_matrix,index):
    TP,TN,FP,FN = tablo(confusion_matrix,index)
    recall = TP/(TP+FN)
    return recall

# %%
print(classification_report(test_labels, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.44      0.52        55
#            1       0.44      0.40      0.42        52
#            2       0.32      0.59      0.42        44
#            3       0.42      0.29      0.34        49
#
#     accuracy                           0.42       200
#    macro avg       0.45      0.43      0.42       200
# weighted avg       0.46      0.42      0.43       200

# %%
for i in range(4):
    print(f"\n{i} acc:", acc(conf_matrix,i))
    print(f"{i} precision:", precision(conf_matrix,i))
    print(f"{i} sensitivity:", sensitivity(conf_matrix,i))
    print(f"{i} specificity:", specificity(conf_matrix,i))
    print(f"{i} f_score:", precision(conf_matrix,i))
    print(f"{i} recall:", recall(conf_matrix,i))
# Out:
# 0 acc: 0.775
# 0 precision: 0.631578947368421
# 0 sensitivity: 0.43636363636363634
# 0 specificity: 0.903448275862069
# 0 f_score: 0.631578947368421
# 0 recall: 0.43636363636363634
#
# 1 acc: 0.71
# 1 precision: 0.4375
# 1 sensitivity: 0.40384615384615385
# 1 specificity: 0.8175675675675675
# 1 f_score: 0.4375
# 1 recall: 0.40384615384615385
#
# 2 acc: 0.635
# 2 precision: 0.32098765432098764
# 2 sensitivity: 0.5909090909090909
# 2 specificity: 0.6474358974358975
# 2 f_score: 0.32098765432098764
# 2 recall: 0.5909090909090909
#
# 3 acc: 0.73
# 3 precision: 0.42424242424242425
# 3 sensitivity: 0.2857142857142857
# 3 specificity: 0.8741721854304636
# 3 f_score: 0.42424242424242425
# 3 recall: 0.2857142857142857

# %%
f_score(conf_matrix,3)
# Out:
# 0.34146341463414637

# %%
sensitivity(conf_matrix,3)
# Out:
# 0.2857142857142857

# %%
gosterTest(1)

# %%
gosterTest(10)

# %%
tahmin_class = [np.argmax(i) for i in tahminler]
tahmin_class[10:20]
# Out:
# [1, 2, 1, 1, 2, 3, 1, 3, 2, 1]

# %%
test_labels[10:20]
# Out:
# array([3, 2, 0, 3, 3, 3, 1, 3, 3, 1])

# %%
print(classification_report(test_labels, tahmin_class,target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.63      0.44      0.52        55
#        other       0.44      0.40      0.42        52
#          sad       0.32      0.59      0.42        44
#        happy       0.42      0.29      0.34        49
#
#     accuracy                           0.42       200
#    macro avg       0.45      0.43      0.42       200
# weighted avg       0.46      0.42      0.43       200
